# %%
import pandas as pd

df1 = pd.read_csv("E:/Data_exploration/GitHub/paraphraser_code/data/candidates/annotated_sentences_mbart_v1.csv")
df2 = pd.read_csv("E:/Data_exploration/GitHub/paraphraser_code/data/candidates/annotated_sentences_ul2_v1.csv")
df3 = pd.read_csv("E:/Data_exploration/GitHub/paraphraser_code/data/candidates/annotated_sentences_mbart_v2.csv")
df4 = pd.read_csv("E:/Data_exploration/GitHub/paraphraser_code/data/candidates/annotated_sentences_ul2_v2.csv")
df5 = pd.read_csv("E:/Data_exploration/GitHub/paraphraser_code/data/candidates/annotated_sentences_mbart_v3.csv")
df6 = pd.read_csv("E:/Data_exploration/GitHub/paraphraser_code/data/candidates/annotated_sentences_ul2_v3.csv")
df7 = pd.read_csv("E:/Data_exploration/GitHub/paraphraser_code/data/candidates/annotated_sentences_mbart_v4.csv")
df8 = pd.read_csv("E:/Data_exploration/GitHub/paraphraser_code/data/candidates/annotated_sentences_ul2_v4.csv")
df9 = pd.read_csv("E:/Data_exploration/GitHub/paraphraser_code/data/candidates/annotated_sentences_ul2_v3_late.csv")
df10 = pd.read_csv("E:/Data_exploration/GitHub/paraphraser_code/data/candidates/annotated_sentences_mbart_v3_late.csv")
df11 = pd.read_csv("E:/Data_exploration/GitHub/paraphraser_code/data/candidates/annotated_sentences_mbart_v4_late.csv")
df12 = pd.read_csv("E:/Data_exploration/GitHub/paraphraser_code/data/candidates/annotated_sentences_ul2_mc4.csv")

# Concatenate dataframes
#combined_df = pd.concat([df1, df2], axis=1)

# Use combine_first to fill missing values from df2 into df1
#combined_df = df1.combine_first(df2)
#combined_df

# %%
result_df = df1#.drop(columns='Unnamed: 0')
dataframes= [df2,df3,df4,df5,df6,df7,df8,df9,df10,df11, df12]
for df in dataframes:
    result_df = result_df.merge(df, on=['original', 'source', 'target'], how='outer') #df.drop(columns='Unnamed: 0')
result_df = result_df.drop_duplicates(subset=['original', 'source', 'target']).reset_index(drop=True)
##columns_to_drop = []
#for item in result_df.columns:
#    if 'Unnamed' in item:
#        columns_to_drop.append(item)

#result_df = result_df.drop(columns=columns_to_drop)
result_df
# Out:
#                                               original  \
# 0                               mw vanmorgen gedoucht.
# 1    Alles schoon aan gedaan kon geen schonen BH vi...
# 2      Kleding die erhing heb ik in de wasmand gedaan.
# 3                       Bed was schoon dit op gemaakt.
# 4                                         Dank je wel.
# ..                                                 ...
# 278           O: Er zitten vlekjes op de bovenkleding.
# 279  Dhr schoon ondergoed en schone bovenkleding aa...
# 280  lichwelb  O; De hr heeft in de ochtend mee geg...
# 281  partixipatie nacht s ik wil dat je me ogen dru...
# 282  S - mw wilde nog tv kijken maar toch gevraagd ...
#
#                                                 source  \
# 0                          mevrouw vanmorgen gedoucht.
# 1    Alles schoon aan gedaan kon geen schonen BH vi...
# 2      Kleding die erhing heb ik in de wasmand gedaan.
# 3                       Bed was schoon dit op gemaakt.
# ...

# %%
result_df.to_csv('E:/Data_exploration/GitHub/paraphraser_code/data/candidates/candidates_annotated_sentences.csv', index=False)
